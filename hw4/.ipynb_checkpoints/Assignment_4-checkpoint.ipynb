# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# # <center> CS587 </center>
# ## <center> Connect to GitHub
# ### To collect and create charts for the number of issues created, closed, etc. for different Repos on GitHub   </center>
#
#
# <br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
#
# ### Requirements:
# - Retrieve the data from GitHub for the different Repos
# - Execute basic descriptive analytics tasks and create charts for the repos and issues
#
#
#
# <br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <br>
#
# ##  You need to install  GitHub package as follows before running the script:
# - pip install PyGithub
#
#     <br>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <br>
#
#
#
#
# ## You need to create a personal account on GitHub and create your GitHub personal access tokens - API key to use GitHub
#
# <br>
# <br>
#
# ### Here are the URLs to guide you on how to generate your GitHub access token
# - https://help.github.com/articles/creating-an-access-token-for-command-line-use/
# - https://docs.github.com/en/github/authenticating-to-github/keeping-your-account-and-data-secure/creating-a-personal-access-token
# - https://docs.github.com/en/rest/overview/other-authentication-methods#via-oauth-and-personal-access-tokens
#
#
# ### Create your personal account and your GitHub personal access tokens from the following URLs:
# - https://docs.github.com/en/get-started/signing-up-for-github/signing-up-for-a-new-github-account
# - https://github.com/settings/tokens
#
# <br>

# %%
import pandas as pd


from math import isnan
import numpy as np

import plotly
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import plotly.express as px



from github import Github

import datetime
from datetime import datetime, date, timedelta
import time

from dateutil.relativedelta import relativedelta
Chart")
# plt.show();
# Out:
#   Input In [48]
#     Chart")
#            ^
# SyntaxError: EOL while scanning string literal

# %%
# You need to work on the data for the past 2 Years
# But for Testing and Debugging  purposes, look for the past 2 months
# Your final submission must be based on the data for the past 2 Years

# since_date = datetime.now() - relativedelta(years=2)
# since_date = datetime.now() - relativedelta(months=1)


since_date = datetime.now() - relativedelta(days=1)
# since_date = datetime.now() - relativedelta(minutes=6)
since_date = datetime.now() - relativedelta(months=2)
print(since_date)

# %%
# For final submission you must include all repos listed below
repos=["angular/angular","angular/material","angular/angular-cli","SebastianM/angular-google-maps","d3/d3"]

# For unit testing and debugging use only the following repos
# repos=["SebastianM/angular-google-maps","d3/d3"]

# %% [markdown]
# <div class="alert alert-info">
#
#
#
# ## Create the GitHub object using your GitHub API KEY
#
#
# </div>

# %%
# g = Github("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e")
# g = Github("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")
g = Github("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")
print("the since date is:   ", since_date)
# dir(g.get_repo)

# %% [markdown]
# <div class="alert alert-success">
#
# # Get data for the following Repos:
#
#
# - "angular/angular"
# - "angular/material"
# - "angular/angular-cli"
# - "SebastianM/angular-google-maps"
# - "d3/d3"
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
#
#
# ## Define the method to get issues/repos data
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
#
# ### You need to add the defesive coding to check for None, NaN, etc. values
#
#
# <br>
#
# ### The following code snippets are meant to coach you on how to get the Repos Data from GitHub
# ### It is your responsibility to write code to work on healthy (not messy) data
#
#
# </div>

# %%
# Get GitHub data for every repo 
print("the since date is:   ", since_date)
get_issues_l1, get_pulls_l1, get_releases_l1, get_branches_l1, get_stats_contributors_l1, last_l1,repo_l1 = [], [], [], [], [], [], []
dict_all = {"angular/angular":[], "angular/material": [], "angular/angular-cli": [], "SebastianM/angular-google-maps": [], "d3/d3": []}

get_issues_l2, get_pulls_l2, get_releases_l2, get_branches_l2, get_stats_contributors_l2, last_l1, repo_l2 = [], [], [], [], [], [], []
dict_all2 = {"angular/angular":[], "angular/material": [], "angular/angular-cli": [], "SebastianM/angular-google-maps": [], "d3/d3": []}
dict_all3 = {"angular/angular":[], "angular/material": [], "angular/angular-cli": [], "SebastianM/angular-google-maps": [], "d3/d3": []}
def getReposData():
    
    for repo in repos:
        repository = g.get_repo(repo)
        print('repo:', repo)
#         print(help(repository.get_issues))
#         print("*" * 50)

        for issue in repository.get_issues(state='all',since=since_date,sort='created'):
#             print(dir(issue))

            if issue.closed_at is not None:
                print("--------------closed-----------------")
                print(repository, issue, issue.closed_at )
                get_issues_l1.append([repository, issue, issue.closed_at])
                dict_all.get(repo).append([repository, issue, issue.closed_at])
            if issue.created_at is not None:
                print("--------------created-----------------")
                print(repository, issue, issue.created_at )  
                get_issues_l2.append([repository, issue, issue.created_at])
                dict_all2.get(repo).append([repository, issue, issue.created_at])
        
#         for pull in repository.get_pulls(state='all'): 
#             if pull is not None:
#                 print(repository, pull)
#                 get_pulls_l1.append([repository, pull])

        
#         for release in repository.get_releases():
#             if release is not None:
#                 print(repository, release)
#                 get_releases_l1.append([repository, release])
        
#         for branch in repository.get_branches():
#             commit = repository.get_commit(branch.commit.sha)
#             if branch is not None:
#                     print(repository, branch)
#                     get_branches_l1([repository, branch])
        
#         for contributor in repository.get_stats_contributors():
#             author_id = contributor.author.id
            
#             for week in contributor.weeks:
#                 print(repository, contributor, week)
#                 get_stats_contributors_l1.append([repository, contributor, week])
        
        print("the forks startting:    ........................")
        
        print(repo, repository.created_at, repository.forks_count)
        last_l1.append([repo, repository.created_at, repository.forks_count])
        dict_all3.get(repo).append([repo, repository.created_at, repository.forks_count])
        print("the forks ending:    ........................")
        #return dict_all,repo_l1,get_issues_l1,dict_all2,repo_l2,get_issues_l2,last_l1
    return dict_all,dict_all2,dict_all3

#     return get_issues_l1,get_pulls_l1,get_releases_l1, get_branches_l1, get_stats_contributors_l1, last_l1

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
#
# ### Get the data for our repos from  GitHub
#
#
# <br>
#
# </div>

# %%
#getReposData()
# get_issues_l1, get_pulls_l1, get_releases_l1, get_branches_l1, get_stats_contributors_l1, last_l1 = getReposData()
# dict_all, repo_l1,get_issues_l1, dict_all2, repo_l2,get_issues_l2 = getReposData()
dict_all, dict_all2, dict_all3 = getReposData()
# Out:
# repo: angular/angular
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Controls inside FormBuilder.group<T>() are not typed", number=46432) 2022-06-20 02:29:39
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: fix base href haser tag", number=46431) 2022-06-19 14:36:26
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Docs: Broken html tag appears in a note", number=46430) 2022-06-19 13:26:46
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="fix(docs-infra): slightly improve aio-top-menu css", number=46429) 2022-06-19 11:41:10
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Angular Elements tutorial uses deprecated class ComponentFactoryResolver", number=46428) 2022-06-19 11:04:10
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Add more validator in `Validators`", number=46427) 2022-06-19 08:03:19
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs(core): add full example for IfLoadedDirective", number=46425) 2022-06-18 13:09:25
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Specific statement is incorrect", number=46424) 2022-06-18 12:21:28
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Package "@angular/bazel" was found but does not support schematics.", number=46423) 2022-06-18 11:54:10
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): make di error messages tree shakable", number=46422) 2022-06-18 03:49:44
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="The type of falsy property is not properly inferred within the template of `*ngIf` directive", number=46421) 2022-06-18 06:29:03
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="The type of falsy property is not properly inferred within the template of `*ngIf` directive", number=46421) 2022-06-17 22:50:20
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Contradictory guidelines in Style 05-18 (strictPropertyInitialization)", number=46420) 2022-06-17 20:10:34
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Angular 13.3 -> 14 Error: NG0203: inject() must be called from an injection context (a constructor, a factory function or a field initializer)", number=46419) 2022-06-17 22:00:24
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Angular 13.3 -> 14 Error: NG0203: inject() must be called from an injection context (a constructor, a factory function or a field initializer)", number=46419) 2022-06-17 17:24:16
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Angular DevTools: Profiler, show infinite changes by Window.addEventListener:message", number=46417) 2022-06-17 13:09:23
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="bug in angular.jp", number=46416) 2022-06-17 13:04:03
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="bug in angular.jp", number=46416) 2022-06-17 12:44:58
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Component Styles are not shared anymore but duplicated per component with Ivy", number=46418) 2022-06-17 18:09:13
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Component Styles are not shared anymore but duplicated per component with Ivy", number=46418) 2022-06-17 12:02:52
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Image loaders url build", number=46414) 2022-06-17 23:04:08
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Image loaders url build", number=46414) 2022-06-17 10:21:02
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="angular-language-service for emacs", number=46413) 2022-06-17 15:02:11
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="angular-language-service for emacs", number=46413) 2022-06-17 10:02:29
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: add bezael to GDE resources", number=46412) 2022-06-17 09:31:55
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: add dany paredes to GDE resources", number=46411) 2022-06-17 09:09:50
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="AbstractControl pristine and dirty properties behaviour", number=46410) 2022-06-17 09:05:42
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Dependency Injection - doc questions unclear", number=46409) 2022-06-17 08:17:24
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Application stays in memory even after being destroyed", number=46408) 2022-06-17 06:22:59
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="fix(core): handle NgModules with standalone pipes in TestBed correctly ", number=46407) 2022-06-17 05:55:53
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Bug in angular.jp website", number=46406) 2022-06-17 07:38:29
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Bug in angular.jp website", number=46406) 2022-06-17 05:40:27
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Ability to set a custom message while working with `Validators`", number=46405) 2022-06-17 05:35:44
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="feat(platform-browser, platform-server): async platform TransferState serializing", number=46404) 2022-06-17 05:29:43
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="domNode not being garbage collected by browser, causing major memory leak", number=46403) 2022-06-17 06:02:51
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="domNode not being garbage collected by browser, causing major memory leak", number=46403) 2022-06-17 03:14:54
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="fix(service-worker): navigationUrls condition check", number=46402) 2022-06-18 19:30:20
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="fix(service-worker): navigationUrls condition check", number=46402) 2022-06-17 01:54:25
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="feat(common): make the `CommonModule` pipes standalone", number=46401) 2022-06-17 00:22:34
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Add experimental package exports @angular/*/experiments", number=46400) 2022-06-17 08:53:25
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Add experimental package exports @angular/*/experiments", number=46400) 2022-06-17 00:12:46
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Backwards compatibility with previous versions", number=46398) 2022-06-16 23:41:15
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Backwards compatibility with previous versions", number=46398) 2022-06-16 22:21:39
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="fix(core): make parent injector argument required in `createEnvironmentInjector`", number=46397) 2022-06-17 16:17:31
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="fix(core): make parent injector argument required in `createEnvironmentInjector`", number=46397) 2022-06-16 22:12:52
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="nyc instrumentation on the Angular ts files having decorators then it moves the export before the decorator so compilation is failed", number=46396) 2022-06-16 20:32:21
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="nyc instrumentation on the Angular ts files having decorators then it moves the export before the decorator so compilation is failed", number=46396) 2022-06-16 20:20:49
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="FormGroup inheritance breaks [formGroup] directive", number=46395) 2022-06-16 23:10:03
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="FormGroup inheritance breaks [formGroup] directive", number=46395) 2022-06-16 20:18:28
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="CanMatch fixes", number=46394) 2022-06-17 16:18:15
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="CanMatch fixes", number=46394) 2022-06-16 17:39:26
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Use CurrencyPipe to output ONLY currency symbol", number=46393) 2022-06-16 14:54:38
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Use CurrencyPipe to output ONLY currency symbol", number=46393) 2022-06-16 14:29:12
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Expose interface type for HTTP request options parameters", number=46392) 2022-06-16 23:17:30
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Expose interface type for HTTP request options parameters", number=46392) 2022-06-16 13:51:18
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="unicode letters (as in valid JS identifiers) not allowed in template", number=46391) 2022-06-16 13:59:50
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="unicode letters (as in valid JS identifiers) not allowed in template", number=46391) 2022-06-16 13:42:20
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Typed Form FormControl value cannot be initialized to null ", number=46390) 2022-06-16 23:44:04
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Typed Form FormControl value cannot be initialized to null ", number=46390) 2022-06-16 13:14:23
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="build: update all non-major dependencies", number=46389) 2022-06-16 12:55:11
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs(router): fix errors in CanMatch examples", number=46388) 2022-06-16 16:33:26
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs(router): fix errors in CanMatch examples", number=46388) 2022-06-16 11:13:19
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="CurrencyPipe: Setting LOCALE_ID does not change _defaultCurrencyCode", number=46387) 2022-06-16 11:48:12
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="CurrencyPipe: Setting LOCALE_ID does not change _defaultCurrencyCode", number=46387) 2022-06-16 11:04:33
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="`canMatch` check throws `NullInjectorError` for a guard provided at the route level", number=46386) 2022-06-17 16:18:15
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="`canMatch` check throws `NullInjectorError` for a guard provided at the route level", number=46386) 2022-06-16 10:37:51
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="SSR style property binding with `null` or `undefined` results invalid/empty style property", number=46385) 2022-06-16 07:42:32
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="feat(docs-infra): add open_in_new icon to external nav-item links", number=46384) 2022-06-16 07:25:17
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(platform-browser):remove unused code in dom sanitization ser…", number=46383) 2022-06-16 05:06:27
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): align tree shakable error messages to the new format", number=46382) 2022-06-16 16:32:50
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): align tree shakable error messages to the new format", number=46382) 2022-06-16 02:42:50
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Retrieve all route segments configuration by URL", number=46381) 2022-06-15 21:11:18
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: fix link to unpkged locales", number=46379) 2022-06-15 21:05:19
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: fix link to unpkged locales", number=46379) 2022-06-15 19:45:18
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Currency bug with MT currency", number=46378) 2022-06-15 19:41:45
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Currency bug with MT currency", number=46378) 2022-06-15 18:59:26
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.1.0-next.1" with changelog.", number=46377) 2022-06-15 17:58:31
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.1.0-next.1" with changelog.", number=46377) 2022-06-15 17:58:08
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: release notes for the v14.0.2 release", number=46376) 2022-06-15 17:29:09
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: release notes for the v14.0.2 release", number=46376) 2022-06-15 17:28:53
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.0.2" with changelog.", number=46375) 2022-06-15 17:27:16
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.0.2" with changelog.", number=46375) 2022-06-15 17:26:38
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: add dany paredes to GDE resources", number=46374) 2022-06-15 17:45:15
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: add dany paredes to GDE resources", number=46374) 2022-06-15 13:40:10
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Tree-Shaking not working for unused but imported Standalone Components ", number=46373) 2022-06-16 23:21:16
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Tree-Shaking not working for unused but imported Standalone Components ", number=46373) 2022-06-15 11:30:57
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Angular issue on custom compiler module", number=46372) 2022-06-15 08:31:03
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Angular issue on custom compiler module", number=46372) 2022-06-15 08:09:08
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Request to keep User Input documentation that has been marked for archival", number=46371) 2022-06-15 07:59:22
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): align tree shakable error messages to new format", number=46370) 2022-06-15 21:05:58
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): align tree shakable error messages to new format", number=46370) 2022-06-15 05:42:25
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: Add missing line in *zone-flags* file. Original referenced from [now achieve](angular.io/guide/user-input#source-code)", number=46369) 2022-06-15 21:04:48
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: Add missing line in *zone-flags* file. Original referenced from [now achieve](angular.io/guide/user-input#source-code)", number=46369) 2022-06-15 04:18:34
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): throw an error if an absolute URL is passed to Image Loaders", number=46368) 2022-06-16 16:27:06
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): throw an error if an absolute URL is passed to Image Loaders", number=46368) 2022-06-14 22:17:21
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Revert "fix(common): sanitize `rawSrc` and `rawSrcset` values in NgOptimizedImage directive"", number=46367) 2022-06-15 06:04:39
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Revert "fix(common): sanitize `rawSrc` and `rawSrcset` values in NgOptimizedImage directive"", number=46367) 2022-06-14 21:37:50
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="ci: override existing snapshot tag if publish snapshot job is restarted", number=46366) 2022-06-15 15:58:04
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="ci: override existing snapshot tag if publish snapshot job is restarted", number=46366) 2022-06-14 20:36:50
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Error building project using artifacts created from angular source code build", number=46365) 2022-06-14 20:11:03
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="fix(animations): reset the start and done fns on player reset", number=46364) 2022-06-14 19:19:05
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="feat(docs-infra): show dark scrollbars in dark mode", number=46363) 2022-06-15 15:56:47
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="feat(docs-infra): show dark scrollbars in dark mode", number=46363) 2022-06-14 16:29:47
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Add an async variant of null validator", number=46362) 2022-06-14 15:38:30
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="ViewEncapsulation.None does not work with AOT in production build", number=46361) 2022-06-14 13:34:12
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="ViewEncapsulation.None does not work with AOT in production build", number=46361) 2022-06-14 13:03:41
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Style binding + style animation + non-reused route + emulated encapsulation breaks route transition animation", number=46360) 2022-06-14 09:36:18
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs(core): fix broken link <BLANK LINE> Dead link is updated with ne…", number=46359) 2022-06-14 15:55:52
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs(core): fix broken link <BLANK LINE> Dead link is updated with ne…", number=46359) 2022-06-14 09:07:09
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="ngModel and ngModelChange order are affecting the process", number=46357) 2022-06-14 07:29:24
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="ngModel and ngModelChange order are affecting the process", number=46357) 2022-06-14 07:11:40
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(compiler-cli): add `forceEmit` flag to `performCompilation`", number=46355) 2022-06-14 15:56:40
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(compiler-cli): add `forceEmit` flag to `performCompilation`", number=46355) 2022-06-13 21:22:43
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="route with only canActiveGuard ", number=46354) 2022-06-13 22:57:25
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="route with only canActiveGuard ", number=46354) 2022-06-13 19:40:12
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="JSON Pipe fails to display properties of type MAP", number=46353) 2022-06-13 20:12:51
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="JSON Pipe fails to display properties of type MAP", number=46353) 2022-06-13 19:34:25
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs:  Adding a book "Angular from Scratch"", number=46352) 2022-06-13 20:59:19
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs:  Adding a book "Angular from Scratch"", number=46352) 2022-06-13 18:46:01
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Missing `standalone` components declared with `button[custom-button]` are not reported by the compiler", number=46351) 2022-06-13 09:50:38
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="NgIf doesn't work properly in case of async event ", number=46350) 2022-06-13 08:01:03
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="NgIf doesn't work properly in case of async event ", number=46350) 2022-06-13 07:15:55
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title=""export 'ɵRuntimeError' was not found in '@angular/core' in angular 11", number=46349) 2022-06-13 06:30:23
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title=""export 'ɵRuntimeError' was not found in '@angular/core' in angular 11", number=46349) 2022-06-13 04:13:35
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs(core): fix broken link <BLANK LINE> Dead link is updated with new, working, and updated link. ", number=46348) 2022-06-14 08:52:54
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs(core): fix broken link <BLANK LINE> Dead link is updated with new, working, and updated link. ", number=46348) 2022-06-13 02:57:32
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="feat(docs-infra): redesign contributors page", number=46347) 2022-06-12 21:13:10
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="loadChildren in Angular 14 causes Maximum call stack size exceeded error", number=46346) 2022-06-13 06:31:21
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="loadChildren in Angular 14 causes Maximum call stack size exceeded error", number=46346) 2022-06-12 15:57:02
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs(core): update `owasp guide project` reference url to latest owasp site", number=46345) 2022-06-12 10:56:47
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="build: update angular version of in-memory-web-api", number=46344) 2022-06-13 17:40:12
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="build: update angular version of in-memory-web-api", number=46344) 2022-06-12 09:01:56
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: Adding a book "Angular from Scratch" in the resources", number=46343) 2022-06-14 16:59:45
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: Adding a book "Angular from Scratch" in the resources", number=46343) 2022-06-12 03:24:56
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="FormGroup valueChanges type is Partial<T> but should be just T", number=46341) 2022-06-11 19:58:59
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="FormGroup valueChanges type is Partial<T> but should be just T", number=46341) 2022-06-11 18:48:36
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="FormBuilder.group controls with array values requires an extra [ ]", number=46340) 2022-06-14 17:44:26
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="FormBuilder.group controls with array values requires an extra [ ]", number=46340) 2022-06-11 14:24:07
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Missing? documentation for localize in angular libraries.", number=46339) 2022-06-12 13:28:22
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Missing? documentation for localize in angular libraries.", number=46339) 2022-06-11 08:30:08
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Update Docs for FormGroups with Optional Nested Objects", number=46338) 2022-06-14 21:51:50
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Update Docs for FormGroups with Optional Nested Objects", number=46338) 2022-06-11 07:30:36
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Update Docs for Typed FormArray", number=46337) 2022-06-15 20:25:11
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Update Docs for Typed FormArray", number=46337) 2022-06-11 07:23:33
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): add missing format error call in NgOptimizedImage", number=46336) 2022-06-13 09:02:55
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): add missing format error call in NgOptimizedImage", number=46336) 2022-06-11 05:17:52
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="fix(core): Resolve forwardRef declarations for jit", number=46334) 2022-06-13 17:00:09
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="fix(core): Resolve forwardRef declarations for jit", number=46334) 2022-06-10 20:55:42
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Private Component Members Are Accessible in Template if Done From Within a FormGroup", number=46333) 2022-06-11 19:10:01
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Private Component Members Are Accessible in Template if Done From Within a FormGroup", number=46333) 2022-06-10 19:22:17
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="angular-in-memory-web-api Angular 14 support", number=46332) 2022-06-13 17:40:13
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="angular-in-memory-web-api Angular 14 support", number=46332) 2022-06-10 17:50:44
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Update instructions should include the context in which to run the update command", number=46331) 2022-06-10 17:41:18
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: Add kevindaviladev to contributors", number=46330) 2022-06-10 17:58:58
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: Add kevindaviladev to contributors", number=46330) 2022-06-10 16:09:21
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Added new contributor", number=46329) 2022-06-10 16:02:14
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Added new contributor", number=46329) 2022-06-10 14:43:12
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Image loaders refactoring", number=46327) 2022-06-13 21:44:12
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Image loaders refactoring", number=46327) 2022-06-10 13:02:24
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Image loaders test cleanup and the ensurePreconnect fix", number=46326) 2022-06-10 21:55:38
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Image loaders test cleanup and the ensurePreconnect fix", number=46326) 2022-06-10 10:46:39
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Cannot use pathMatch without redirect or component, etc anymore regression ", number=46325) 2022-06-10 15:03:53
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Cannot use pathMatch without redirect or component, etc anymore regression ", number=46325) 2022-06-10 09:47:41
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="fix(docs-infra): add missing aria-labels to contributors page", number=46324) 2022-06-10 16:09:29
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="fix(docs-infra): add missing aria-labels to contributors page", number=46324) 2022-06-09 21:38:39
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Support for default exports in `loadChildren` and `loadComponent` callbacks", number=46323) 2022-06-09 21:04:12
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="feat(common): add warnings re: image distortion", number=46322) 2022-06-10 20:19:49
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="feat(common): add warnings re: image distortion", number=46322) 2022-06-09 19:48:14
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(router): clean up internal hooks", number=46321) 2022-06-10 15:24:01
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(router): clean up internal hooks", number=46321) 2022-06-09 16:33:42
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="NgIf doesn't work properly in case of async event ", number=46320) 2022-06-09 17:34:18
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="NgIf doesn't work properly in case of async event ", number=46320) 2022-06-09 16:14:45
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): remove code duplication in loaders", number=46319) 2022-06-09 17:50:09
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): remove code duplication in loaders", number=46319) 2022-06-09 10:36:12
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Error building Angular source code", number=46317) 2022-06-09 06:05:38
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Error building Angular source code", number=46317) 2022-06-09 05:26:20
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="VM1689 angular.js:15697 NullInjectorError: StaticInjectorError(AppModule)[UserFeedbackService -> http_HttpClient]:    StaticInjectorError(Platform: core)[UserFeedbackService -> http_HttpClient]:      NullInjectorError: No provider for http_HttpClient!", number=46316) 2022-06-09 15:53:25
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="VM1689 angular.js:15697 NullInjectorError: StaticInjectorError(AppModule)[UserFeedbackService -> http_HttpClient]:    StaticInjectorError(Platform: core)[UserFeedbackService -> http_HttpClient]:      NullInjectorError: No provider for http_HttpClient!", number=46316) 2022-06-09 03:03:54
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="feat(common): add cloudflare loader", number=46315) 2022-06-09 09:37:03
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="feat(common): add cloudflare loader", number=46315) 2022-06-09 03:01:33
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: clarify OnPush", number=46314) 2022-06-10 14:21:33
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: clarify OnPush", number=46314) 2022-06-09 02:49:31
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Enable runfiles", number=46313) 2022-06-14 16:58:31
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Enable runfiles", number=46313) 2022-06-08 22:41:37
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs(core): Updated doc to encourage use of non-deprecated API instead of the deprecated ComponentFactory", number=46312) 2022-06-17 12:16:43
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs(core): Updated doc to encourage use of non-deprecated API instead of the deprecated ComponentFactory", number=46312) 2022-06-08 21:04:37
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.1.0-next.0" with changelog.", number=46311) 2022-06-08 20:32:37
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.1.0-next.0" with changelog.", number=46311) 2022-06-08 20:27:43
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="build: exclude bazel commits from release notes", number=46310) 2022-06-08 20:42:38
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="build: exclude bazel commits from release notes", number=46310) 2022-06-08 20:09:04
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: release notes for the v14.0.1 release", number=46309) 2022-06-08 20:20:45
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: release notes for the v14.0.1 release", number=46309) 2022-06-08 20:08:16
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.0.1" with changelog.", number=46308) 2022-06-08 20:06:07
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.0.1" with changelog.", number=46308) 2022-06-08 20:03:19
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.0.1" with changelog.", number=46307) 2022-06-08 19:57:36
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.0.1" with changelog.", number=46307) 2022-06-08 19:56:17
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Please add a guide to upgrade Angular Universal apps in the upgrade guide.", number=46306) 2022-06-08 17:17:45
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Bind to Observable/Promise directly in HostBinding", number=46305) 2022-06-08 16:03:50
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Bind to Observable/Promise directly in HostBinding", number=46305) 2022-06-08 15:30:07
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: update example hero ID", number=46304) 2022-06-09 20:46:05
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: update example hero ID", number=46304) 2022-06-08 15:19:46
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="New discussion button doesn't work", number=46303) 2022-06-08 13:08:53
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="New discussion button doesn't work", number=46303) 2022-06-08 12:55:34
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): allow loaders to specify the ensurePreconnect option", number=46302) 2022-06-08 19:33:09
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): allow loaders to specify the ensurePreconnect option", number=46302) 2022-06-08 12:52:58
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="fix(compiler-cli): don't emit empty providers array", number=46301) 2022-06-10 14:27:26
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="fix(compiler-cli): don't emit empty providers array", number=46301) 2022-06-08 11:07:52
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.0.1" with changelog.", number=46300) 2022-06-08 09:41:42
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Bump version to "v14.0.1" with changelog.", number=46300) 2022-06-08 09:41:30
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs(forms): fix `FormRecord` usage notes", number=46299) 2022-06-08 20:52:30
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs(forms): fix `FormRecord` usage notes", number=46299) 2022-06-08 09:38:18
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Wrong example of FormRecord usage", number=46298) 2022-06-08 23:05:52
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Wrong example of FormRecord usage", number=46298) 2022-06-08 09:10:40
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="zone.js Mocha patch regression in v0.11.5", number=46297) 2022-06-08 08:59:43
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Type 'ModuleWithProviders<...>' is not assignable to type 'any[] | Type<any>' in v14", number=46296) 2022-06-08 11:50:41
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Type 'ModuleWithProviders<...>' is not assignable to type 'any[] | Type<any>' in v14", number=46296) 2022-06-08 06:28:37
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): move LCP image observer to a separate file", number=46295) 2022-06-08 09:16:19
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(common): move LCP image observer to a separate file", number=46295) 2022-06-08 05:41:17
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="test(common): optimize image loader tests of the NgOptimizedImage directive", number=46294) 2022-06-08 22:36:54
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="test(common): optimize image loader tests of the NgOptimizedImage directive", number=46294) 2022-06-07 22:20:09
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Angular 13 - yyyy/MMM/dd Date format - not working for Sepetember month in en-GB LOCALE_ID", number=46293) 2022-06-07 20:56:45
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Angular 13 - yyyy/MMM/dd Date format - not working for Sepetember month in en-GB LOCALE_ID", number=46293) 2022-06-07 19:55:52
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="[13.3.x] build: update dev-infra shared code to latest revision", number=46292) 2022-06-07 18:50:20
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="[13.3.x] build: update dev-infra shared code to latest revision", number=46292) 2022-06-07 17:17:17
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="build: update dev-infra shared code to latest revision", number=46291) 2022-06-07 17:43:43
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="build: update dev-infra shared code to latest revision", number=46291) 2022-06-07 17:12:02
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="Revert "refactor(core): don't use patched data in LifecycleHooksFeatu…", number=46290) 2022-06-07 16:29:36
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Revert "refactor(core): don't use patched data in LifecycleHooksFeatu…", number=46290) 2022-06-07 16:13:17
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="build(devtools): update the extension version", number=46289) 2022-06-10 15:23:21
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="build(devtools): update the extension version", number=46289) 2022-06-07 13:40:49
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="@Output not working properly from global context even with ngzone.run()", number=46288) 2022-06-07 13:54:00
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="@Output not working properly from global context even with ngzone.run()", number=46288) 2022-06-07 13:18:18
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Update Angular DevTools manifest version", number=46287) 2022-06-07 13:09:13
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs(router): Complete `QueryParamsHandling` documentation", number=46286) 2022-06-08 19:41:00
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs(router): Complete `QueryParamsHandling` documentation", number=46286) 2022-06-07 12:08:39
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: remove azure builder reference", number=46285) 2022-06-08 19:40:30
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: remove azure builder reference", number=46285) 2022-06-07 12:06:58
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="routerLink and attr.href work together", number=46284) 2022-06-07 17:50:04
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="routerLink and attr.href work together", number=46284) 2022-06-07 11:31:05
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Passing data into "router-outlet" child components", number=46283) 2022-06-07 09:31:09
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="fix(common): allow null in ngComponentOutlet", number=46280) 2022-06-09 16:04:26
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="fix(common): allow null in ngComponentOutlet", number=46280) 2022-06-07 07:32:05
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="build: update dependency magic-string to v0.26.2", number=46279) 2022-06-07 17:43:17
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="build: update dependency magic-string to v0.26.2", number=46279) 2022-06-07 05:12:02
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="BrowserAnimationsModule error in standalone component", number=46278) 2022-06-07 05:42:15
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="BrowserAnimationsModule error in standalone component", number=46278) 2022-06-07 05:03:50
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="feat(common): add loaders for Cloudinary and ImageKit providers", number=46277) 2022-06-09 09:08:16
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="feat(common): add loaders for Cloudinary and ImageKit providers", number=46277) 2022-06-07 00:50:13
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="angular 14 UntypedFormBuilder", number=46276) 2022-06-07 15:39:03
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="angular 14 UntypedFormBuilder", number=46276) 2022-06-06 21:39:05
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="How to add typing for FormBuilder class doc is missing", number=46275) 2022-06-06 19:34:32
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="How to add typing for FormBuilder class doc is missing", number=46275) 2022-06-06 19:12:42
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(core): export missing util function", number=46274) 2022-06-06 18:35:42
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="refactor(core): export missing util function", number=46274) 2022-06-06 17:47:27
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="docs: add i18n video to the overview page", number=46273) 2022-06-06 18:46:53
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="docs: add i18n video to the overview page", number=46273) 2022-06-06 14:44:59
# --------------created-----------------
# Repository(full_name="angular/angular") Issue(title="Do not convert 'undefined' and 'null' values in HttpParams contructor", number=46272) 2022-06-06 14:03:09
# --------------closed-----------------
# Repository(full_name="angular/angular") Issue(title="build: lock file maintenance", number=46270) 2022-06-06 18:46:36
# ...
# Repository(full_name="angular/angular") PullRequest(title="perf(ivy): store binding metadata in the ngDevMode only", number=32317)
# Repository(full_name="angular/angular") PullRequest(title="8.23", number=32316)
# Repository(full_name="angular/angular") PullRequest(title="docs(platform-browser): remove redundant JSDoc tag from `BROWSER_SANITIZATION_PROVIDERS__POST_R3__`", number=32314)
# Repository(full_name="angular/angular") PullRequest(title="docs: fix typo in compiler options guide", number=32312)
# Repository(full_name="angular/angular") PullRequest(title="fix(ivy): handle expressions in i18n attributes properly", number=32309)
# Repository(full_name="angular/angular") PullRequest(title="ICP1 pull request", number=32305)
# Repository(full_name="angular/angular") PullRequest(title="fix(ngcc): do not analyze dependencies for non Angular entry-points", number=32303)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to ea386e045", number=32298)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to 59722208a", number=32297)
# Repository(full_name="angular/angular") PullRequest(title="docs: fix wrong HttpEventType of HttpResponse class", number=32296)
# Repository(full_name="angular/angular") PullRequest(title="ci: remove unused artifact uploads from test job", number=32292)
# Repository(full_name="angular/angular") PullRequest(title="Cleaning out DomAdapter part 2", number=32291)
# Repository(full_name="angular/angular") PullRequest(title="docs: fix http example to use correct property", number=32288)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to 166cd1501", number=32286)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to 70e761c12", number=32285)
# Repository(full_name="angular/angular") PullRequest(title="docs: remove universalProject option from app shell docs", number=32281)
# Repository(full_name="angular/angular") PullRequest(title="docs: include Ivy enabled by default in breaking changes", number=32279)
# Repository(full_name="angular/angular") PullRequest(title="refactor(core): remove unused or testing-only utilities from DomAdapters", number=32278)
# Repository(full_name="angular/angular") PullRequest(title="build: patch terser to create proper source-maps [do not merge]", number=32277)
# Repository(full_name="angular/angular") PullRequest(title="test: make largetable test work in g3", number=32275)
# Repository(full_name="angular/angular") PullRequest(title="test: make tree test work in g3", number=32274)
# Repository(full_name="angular/angular") PullRequest(title="docs: Use ngOnInit to fetch data from services in the Getting Started guide", number=32273)
# Repository(full_name="angular/angular") PullRequest(title="docs(language-service): update integration test information", number=32269)
# Repository(full_name="angular/angular") PullRequest(title="docs: fixed animations reference links to api", number=32267)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to fcace36a6", number=32266)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to 6d71dfa25", number=32265)
# Repository(full_name="angular/angular") PullRequest(title="Ivy perf enter view refactor", number=32263)
# Repository(full_name="angular/angular") PullRequest(title="docs: Update the aria-valuemax attr of the sample", number=32261)
# Repository(full_name="angular/angular") PullRequest(title="docs: update inline lazy loading example to use the import syntax", number=32260)
# Repository(full_name="angular/angular") PullRequest(title="refactor(ivy): remove styling state storage and introduce direct style writing", number=32259)
# Repository(full_name="angular/angular") PullRequest(title="fix(compiler): correctly parse attributes with a dot in the name", number=32256)
# Repository(full_name="angular/angular") PullRequest(title="ci: update size benchmarks for core", number=32255)
# Repository(full_name="angular/angular") PullRequest(title="docs: add information about running clang-format with Vim", number=32254)
# Repository(full_name="angular/angular") PullRequest(title="build: add .vimrc to .gitignore", number=32253)
# Repository(full_name="angular/angular") PullRequest(title="refactor(language-service): add generic decorator property verifications", number=32252)
# Repository(full_name="angular/angular") PullRequest(title="ci: copy bazelrc files to home RC locations", number=32251)
# Repository(full_name="angular/angular") PullRequest(title="refactor(language-service): Remove redudant 'TemplateInfo' type", number=32250)
# Repository(full_name="angular/angular") PullRequest(title="build: update tslint to version ~5.20.0", number=32248)
# Repository(full_name="angular/angular") PullRequest(title="fix: update all files/directories owned by DevInfra to new DevInfra Framework team alias", number=32247)
# Repository(full_name="angular/angular") PullRequest(title="build: use bazel workers for ngc and tsc in local development", number=32246)
# Repository(full_name="angular/angular") PullRequest(title="test(language-service): Add test for CRLF line endings", number=32245)
# Repository(full_name="angular/angular") PullRequest(title="ci: update material-unit-tests commit [patch]", number=32244)
# Repository(full_name="angular/angular") PullRequest(title="ci: update material-unit-tests commit", number=32243)
# Repository(full_name="angular/angular") PullRequest(title="ci: test", number=32241)
# Repository(full_name="angular/angular") PullRequest(title="build: add blocklist for material unit tests", number=32239)
# Repository(full_name="angular/angular") PullRequest(title="feat(language-service): add definitions for templateUrl", number=32238)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to d2489aeda", number=32236)
# Repository(full_name="angular/angular") PullRequest(title="fix(ivy): ngtsc throws if "flatModuleOutFile" is set to null", number=32235)
# Repository(full_name="angular/angular") PullRequest(title="fix(compiler): return enableIvy true when using `readConfiguration`", number=32234)
# Repository(full_name="angular/angular") PullRequest(title="docs: describe your change...etherminer10## PR Checklist", number=32233)
# Repository(full_name="angular/angular") PullRequest(title="feat(core): add dynamic queries schematic", number=32231)
# Repository(full_name="angular/angular") PullRequest(title="refactor(platform-browser): Hoist functions to workaround optimizatio…", number=32230)
# Repository(full_name="angular/angular") PullRequest(title="docs: update collaborators page", number=32229)
# Repository(full_name="angular/angular") PullRequest(title="docs: add ng deploy to the deployment guide", number=32227)
# Repository(full_name="angular/angular") PullRequest(title="Revert "ci: remove material-unit-tests failure blocklist (#32138)"", number=32226)
# Repository(full_name="angular/angular") PullRequest(title="feat(language-service): add definitions for templateUrl", number=32225)
# Repository(full_name="angular/angular") PullRequest(title="ci: update material commit we use to run integration tests", number=32224)
# Repository(full_name="angular/angular") PullRequest(title="docs(aio): added link to ngRuAir podcast", number=32223)
# Repository(full_name="angular/angular") PullRequest(title="feat(ngcc): support ignoring all entry-points within a package", number=32222)
# Repository(full_name="angular/angular") PullRequest(title="Link to web.dev Service Worker articles from SW guide", number=32221)
# Repository(full_name="angular/angular") PullRequest(title="ci: update material commit we use to run integration tests", number=32220)
# Repository(full_name="angular/angular") PullRequest(title="Make Ivy the default in Angular!", number=32219)
# Repository(full_name="angular/angular") PullRequest(title="Property binding perf improvements", number=32212)
# Repository(full_name="angular/angular") PullRequest(title="docs: fixed a misleading sentence", number=32211)
# Repository(full_name="angular/angular") PullRequest(title="docs: add clarification regarding development in older browsers in Deployment guide", number=32210)
# Repository(full_name="angular/angular") PullRequest(title="fix(compiler): Support for combining host-context and host selectors", number=32209)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): add empty `codeGenApi` JSDoc tag definition", number=32207)
# Repository(full_name="angular/angular") PullRequest(title="refactor(core): remove disabled injectable-pipe migration [patch]", number=32206)
# Repository(full_name="angular/angular") PullRequest(title="fix(ngcc): ignore format properties that exist but are undefined", number=32205)
# Repository(full_name="angular/angular") PullRequest(title="feat(ivy): make Hammer support tree-shakable", number=32203)
# Repository(full_name="angular/angular") PullRequest(title="ci: exclude the upstream g3 branch from building on CI", number=32202)
# Repository(full_name="angular/angular") PullRequest(title="fix(ivy): reset binding index before executing a template in `refreshView` call", number=32201)
# Repository(full_name="angular/angular") PullRequest(title="feat(core): Introduce TestBed.inject to replace TestBed.get", number=32200)
# Repository(full_name="angular/angular") PullRequest(title="fix(ivy): get name directly from nativeNode", number=32198)
# Repository(full_name="angular/angular") PullRequest(title="Clean up formats in template syntax guide", number=32197)
# Repository(full_name="angular/angular") PullRequest(title="perf(ngcc): add support for parallel execution of tasks", number=32196)
# Repository(full_name="angular/angular") PullRequest(title="Position old upgrade setup guide as legacy", number=32193)
# Repository(full_name="angular/angular") PullRequest(title="docs(ivy): update micro-benchmark instructions", number=32190)
# Repository(full_name="angular/angular") PullRequest(title="fix(bazel): pin `@microsoft/api-extractor`", number=32187)
# Repository(full_name="angular/angular") PullRequest(title="fix(bazel): pin `@microsoft/api-extractor`", number=32186)
# Repository(full_name="angular/angular") PullRequest(title="feat(bazel): update to the latest `@microsoft/api-extractor`", number=32185)
# Repository(full_name="angular/angular") PullRequest(title="refactor(core): remove disabled injectable-pipe migration", number=32184)
# Repository(full_name="angular/angular") PullRequest(title="fix(ngcc): handle deep imports that already have an extension", number=32181)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to e0055d293", number=32175)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to 6aae7f563", number=32174)
# Repository(full_name="angular/angular") PullRequest(title="feat(ivy): use the schema registry to check DOM bindings", number=32171)
# Repository(full_name="angular/angular") PullRequest(title="docs: Fix typo on singleton-services.md page", number=32170)
# Repository(full_name="angular/angular") PullRequest(title="Support type-then-feature naming convention", number=32168)
# Repository(full_name="angular/angular") PullRequest(title="Tslib as peerDependency", number=32167)
# Repository(full_name="angular/angular") PullRequest(title=" refactor(ivy): cleanup tests from render3", number=32165)
# Repository(full_name="angular/angular") PullRequest(title="docs: change lite-server baseDir path to output folder", number=32164)
# Repository(full_name="angular/angular") PullRequest(title="test(language-service): Fix diagnostic tests", number=32161)
# Repository(full_name="angular/angular") PullRequest(title="fix(ivy): ngTemplateOutlet error when switching between null and template value", number=32160)
# Repository(full_name="angular/angular") PullRequest(title="perf(ivy): avoid for-of loops at runtime", number=32157)
# Repository(full_name="angular/angular") PullRequest(title="refactor(language-service): Omit typechecking for finding directives", number=32156)
# Repository(full_name="angular/angular") PullRequest(title="perf: don't create holey arrays", number=32155)
# Repository(full_name="angular/angular") PullRequest(title="perf(core): Make `PlatformLocation` tree-shakable", number=32154)
# Repository(full_name="angular/angular") PullRequest(title="docs: fix typo of Typescript to TypeScript", number=32153)
# Repository(full_name="angular/angular") PullRequest(title="refactor(language-service): Cleanup diagnostics", number=32152)
# Repository(full_name="angular/angular") PullRequest(title="Update to nodejs rules 0.37.1", number=32151)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to 43fc440c0", number=32148)
# Repository(full_name="angular/angular") PullRequest(title="build(docs-infra): upgrade cli command docs sources to fe88669c9", number=32147)
# Repository(full_name="angular/angular") PullRequest(title="fix(language-service): Instantiate MetadataResolver once", number=32145)
# Repository(full_name="angular/angular") PullRequest(title="build: add `ngcc` as a valid commit message scope", number=32144)
# Repository(full_name="angular/angular") PullRequest(title="fix(ivy): ensure binding ordering doesn't mess up when a `NO_CHANGE` value is encountered", number=32143)
# Repository(full_name="angular/angular") PullRequest(title="docs(service-worker): mention that `dataGroups` only cache non-mutating requests", number=32142)
# Repository(full_name="angular/angular") PullRequest(title="ci: move bazel saucelabs execution to script to be used across all Angular repos", number=32141)
# Repository(full_name="angular/angular") PullRequest(title="Add detail to Router NavigationCancel event doc", number=32140)
# Repository(full_name="angular/angular") PullRequest(title="Add SwPush notification usage to api doc", number=32139)
# Repository(full_name="angular/angular") PullRequest(title="ci: remove material-unit-tests failure blocklist", number=32138)
# Repository(full_name="angular/angular") PullRequest(title="docs(router): fix router description", number=32136)
# Repository(full_name="angular/angular") PullRequest(title="Hooks refactor", number=32131)
# Repository(full_name="angular/angular") PullRequest(title="feat(core): add undecorated classes with decorated fields schematic", number=32130)
# Repository(full_name="angular/angular") PullRequest(title="Two ngcc fixes", number=32129)
# Repository(full_name="angular/angular") PullRequest(title="Release zone.js 0.10.2", number=32128)
# Repository(full_name="angular/angular") PullRequest(title="refactor(language-service): Differentiate Inline and External template", number=32127)
# Repository(full_name="angular/angular") PullRequest(title="docs: update marketing resources.json with ExtAngular", number=32126)
# Repository(full_name="angular/angular") PullRequest(title="fix(ivy): Support selector-less directive as base classes", number=32125)
# Repository(full_name="angular/angular") PullRequest(title="fix(docs-infra): fix broken toc ul styles", number=32124)
# Repository(full_name="angular/angular") PullRequest(title="fix(platform-browser): loosen KeyEventsPlugin.addEventListener element type", number=32123)
# Repository(full_name="angular/angular") PullRequest(title="perf(ivy): avoid first template pass checks during view creation", number=32120)
# Repository(full_name="angular/angular") PullRequest(title="refactor(language-service): Return ts.CompletionInfo for getCompletionsAt()", number=32116)
# Repository(full_name="angular/angular") PullRequest(title="refactor(language-service): Return ts.Diagnostic[] for getDiagnostics", number=32115)
# Repository(full_name="angular/angular") PullRequest(title="ci: add ivy commits to generated CHANGELOG", number=32114)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
#
# ### Requirement 1:
# - Create Line Chart to plot the number of issues for every Repo
#
#
# <br>
#
# </div>

# %%
# Create a dataframe for ['RepoName','Count']

#Sample code snippets below

#df = pd.DataFrame(...)
#ax = plt.gca()
#df.plot(kind='line',x='RepoName',y='count',ax=ax, title='Issues for every Repo')
#plt.show();

count = [len(dict_all.get('angular/angular')), len(dict_all.get('angular/material')), len(dict_all.get('angular/angular-cli')), len(dict_all.get('SebastianM/angular-google-maps')), len(dict_all.get('d3/d3'))]
print(count)
df = pd.DataFrame({'RepoName': repos, 'count': count})
plt.figure(figsize=(18,5))
ax = plt.gca()
df.plot(kind='line',x='RepoName',y='count',ax=ax, title='Issues for every Repo')
# ax = df.plot()

plt.show();

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
#
# ### Requirement 2:
# - Create Bar Chart to plot the number of issues created every month for every Repo
#
#
# <br>
#
# </div>

# %%
#Create a dataframe for ['RepoName','Month','Count']

#Sample code snippets below
#         df = pd.DataFrame(pd_date4)
#         print("month is: ")
#         df.plot()
#         plt.show()
#         print(allMonth)

def countForEachRepo(repos):
    for repo in repos:
        pd_date2=pd.DataFrame([x for x in dict_all2.get(repo)[:-1]], columns=["eachRepo", "issue", "date"])
#         print(pd_date2.values.tolist())
        
        pd_date2.set_index(["date"], inplace=True)
        pd_date3=pd_date2.head(1000000)
        if not pd_date3.empty:
            pd_date4=pd_date3.resample('M').count()

            print(pd_date4.index.min())
            print(pd_date4.index.max())
            currDate=pd_date4.index.min()
            endDate = pd_date4.index.max()

            allMonth=[ x[0] for x in pd_date4 ]

            dr1 = pd.date_range(pd_date4.index.min(), pd_date4.index.max(), freq='12M')
            print("the dr1: ")
            print(dr1)


            df = pd.DataFrame({'Month': pd_date4.index, "RepoName": repo, "Count": pd_date4["issue"]})
          
            each_start_month = 0
            for i in range(int(str((pd_date4.index.max() - pd_date4.index.min())/365)[0])):
                df2 = df.iloc[each_start_month:each_start_month + 12]
                print("the df is for this show:")
                print(df2)
                plt.figure(figsize=(18,6))
                df2.pivot('Month', 'RepoName', 'Count').plot(kind='bar', title='Issues created for every month for every Repo')
                plt.show()
                each_start_month = each_start_month + 12
        else:
            print("There is no created issue in repo << %s >> yet, so nothing to show for it" %(repo))


countForEachRepo(repos)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
#
# ### Requirement 3:
# - Create Bar Chart to plot the number of forks for every Repo
#
#
# <br>
#
# </div>

# %%
def countForEachRepo(repos):
    for repo in repos:
        pd_date2=pd.DataFrame([x for x in dict_all3.get(repo)], columns=["eachRepo", "date", "count"])
#         print(pd_date2.values.tolist())  
        pd_date3=pd_date2.set_index(["date"], inplace=True)
        pd_date3=pd_date2.head(1000000)
        print(pd_date3)
        if not pd_date3.empty:
            pd_date4=pd_date3
            df = pd.DataFrame({'Date': pd_date4.index, "RepoName": repo, "Count": pd_date4["count"]})
            plt.figure(figsize=(15,6))
            df.pivot('Date', 'RepoName', 'Count').plot(kind='bar', title='plot the number of forks for every Repo')
            plt.show()
        else:
            print("There is no created issue in repo << %s >> yet, so nothing to show for it" %(repo))

countForEachRepo(repos)
# print(dict_all3)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
#
# ### Requirement 4:
# - Create Bar Chart to plot the number of issues closed every week for every Repo
#
#
# <br>
#
# </div>

# %%
#Create a dataframe for ['RepoName','Month','Count']

#Sample code snippets below
import calendar

count_dict={}
def countForEachRepo(repos):
    for repo in repos:
        pd_date2=pd.DataFrame([x for x in dict_all.get(repo)[:-1]], columns=["eachRepo", "issue", "date"])
#         print(pd_date2.values.tolist())
        
        pd_date2.set_index(["date"], inplace=True)
        pd_date3=pd_date2.head(100000)
        
        if not pd_date3.empty:
            pd_date4=pd_date3.resample('W').count()

            print(pd_date4.index.min())
            print(pd_date4.index.max())
            currDate=pd_date4.index.min()
            endDate = pd_date4.index.max()

            df = pd.DataFrame({'Week': pd_date4.index, "RepoName": repo, "Count": pd_date4["issue"]})
          
            each_start_month = 0
            for i in range(int(str((pd_date4.index.max() - pd_date4.index.min())/7)[0])):
                df2 = df.iloc[each_start_month:each_start_month + 12]
                print("the df is for this show:")
                print(df2)
                plt.figure(figsize=(15,6))
                try:
                    df2.pivot('Week', 'RepoName', 'Count').plot(kind='bar', title=' plot the number of issues closed every week for every Repo')
                except:
                    print("at the end, no numeric data to plot")
                plt.show()
                each_start_month = each_start_month + 12
        else:
            print("There is no created issue in repo << %s >> yet, so nothing to show for it" %(repo))

countForEachRepo(repos)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
#
# ### Requirement 5:
# - Create Stacked-Bar Chart to plot the number of created and closed issues for every Repo
#
#
# <br>
#
# </div>

# %%
def countForEachRepo(repos):
    i = 0
    for repo in repos:
        pd_date2=pd.DataFrame([x for x in dict_all2.get(repo)], columns=["eachRepo", "issue", "date"])
        pd_date21=pd.DataFrame([x for x in dict_all.get(repo)], columns=["eachRepo", "issue", "date"])
        
        pd_date3=pd_date2.groupby("eachRepo").count()
        pd_date31=pd_date21.groupby("eachRepo").count()
        i=i+1
        if i>=1:
            if i==1:
                pd_date4=pd_date3
                pd_date41=pd_date31
                print(pd_date41)
            else:
                pd_date4=pd.concat([pd_date4, pd_date3])
                pd_date41=pd.concat([pd_date41, pd_date31])
    if not pd_date4.empty:
        print("===" * 80)
        index1=pd_date4.index.values.tolist()
        index2=pd_date41.index.values.tolist()
        count1=pd_date4["issue"].values.tolist()
        count2=pd_date41["issue"].values.tolist()
        
        num = 0
        for i in index1:
            if i not in index2:
                index2.insert(num, i)
                count2.insert(num, 1)
            num = num + 1
        
        print("index1", index1)
        print("index2", index2)
        print("count1", count1)
        print("count2", count2)
        fig = plt.figure(figsize=(20,6))
        ax = fig.add_subplot(111)
        
        
        x = [1, 2, 9,3,2]
        y1, y2, y3 = [1, 2], [2, 4], [3, 6]

        w = 0.2
        ax.bar(repos, count1, width=w, label='Closed')
        ax.bar(repos, count2, width=w, label='Created')
        ax.legend()
        
        plt.show()
    
    
    else:
        print("There is no created issue in repo << %s >> yet, so nothing to show for it" %(repo))

countForEachRepo(repos)
